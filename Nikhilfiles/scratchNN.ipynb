# %% [markdown]
# Scratch notebook of Nikhil to look at things
#
# I realize I'm pushing this first without anything significant yet lol

# %%
import pickle

file_path = '/Users/nikhilnagabandi/My Drive/Grad_School/Erdos_Institute/github_things/Greenlight-github/spring-2025-greenlight/processed_data/combined_dataset.pkl'

with open(file_path, 'rb') as file:
    data = pickle.load(file)

print(data)
# Out:
#                          final_title  final_budget  final_worldwide_boxoffice  \
# 0                            #Horror     1500000.0                        NaN
# 1                     #Pellichoopulu      200000.0                  5500000.0
# 2                 'N Beetje Verliefd      800000.0                   966214.0
# 3               (500) Days of Summer     7500000.0                 60722734.0
# 4     1. Mai – Helden bei der Arbeit      200000.0                        NaN
# ...                              ...           ...                        ...
# 9545                             피에타      103000.0                  3623330.0
# 9546                              하녀     4000000.0                        NaN
# 9547                             해운대    16000000.0                 11301649.0
# 9548                             회사원     3500000.0                  7339398.0
# 9549            ２０世紀少年< 第1章> 終わりの始まり    20000000.0                 31244858.0
#
#       final_domestic_boxoffice  \
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                   32391374.0
# 4                          NaN
# ...                        ...
# 9545                   21932.0
# 9546                  149757.0
# 9547                       NaN
# 9548                       NaN
# 9549                       NaN
#
#                                            final_genres final_runtime  \
# 0     [{'id': 18, 'name': 'Drama'}, {'id': 9648, 'na...          90.0
# 1     [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...         124.0
# 2     [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...          83.0
# 3     [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...          95.0
# 4                         [{'id': 18, 'name': 'Drama'}]          90.0
# ...                                                 ...           ...
# 9545                      [{'id': 18, 'name': 'Drama'}]         104.0
# 9546  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...         106.0
# 9547  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...         120.0
# 9548  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...          96.0
# 9549  [{'id': 878, 'name': 'Science Fiction'}, {'id'...         142.0
#
#                                          final_overview  final_certificate  \
# 0     Inspired by actual events, a group of 12 year ...                3.0
# 1     Raj Kandukuri and BiG Ben Films in association...                8.2
# 2     Thijs is a ripe-age Dutch tomato grower. His a...                5.4
# 3     Tom (Joseph Gordon-Levitt), greeting-card writ...                7.7
# 4     An eleven-year-old Turkish boy, two young men ...                NaN
# ...                                                 ...                ...
# 9545  A loan shark is forced to reconsider his viole...                7.1
# 9546  A man's affair with his family's housemaid lea...                6.4
# 9547  Man-sik and Yeon-hee, are unsure as to whether...                5.5
# 9548  Hyeong-Do (So Ji-Sub) is an assassin for a com...                6.6
# 9549  In 1969, Kenji, an elementary school kid and h...                6.6
#
#      final_original_language  \
# 0                         de
# 1                         te
# 2                         nl
# 3                         en
# 4                         de
# ...                      ...
# 9545                      ko
# 9546                      ko
# 9547                      ko
# 9548                      ko
# 9549                      ja
#
#                              final_production_countries    imdb_id  \
# 0     [{'iso_3166_1': 'US', 'name': 'United States o...  tt3526286
# 1               [{'iso_3166_1': 'IN', 'name': 'India'}]  tt5824826
# 2         [{'iso_3166_1': 'NL', 'name': 'Netherlands'}]  tt0800164
# 3     [{'iso_3166_1': 'US', 'name': 'United States o...  tt1022603
# 4             [{'iso_3166_1': 'DE', 'name': 'Germany'}]  tt1020932
# ...                                                 ...        ...
# 9545      [{'iso_3166_1': 'KR', 'name': 'South Korea'}]  tt2299842
# 9546      [{'iso_3166_1': 'KR', 'name': 'South Korea'}]  tt1314652
# 9547      [{'iso_3166_1': 'KR', 'name': 'South Korea'}]  tt1153040
# 9548      [{'iso_3166_1': 'KR', 'name': 'South Korea'}]  tt2371486
# 9549  [{'iso_3166_1': 'JP', 'name': 'Japan'}, {'iso_...  tt1155705
#
#                                    production_companies release_date    year  \
# 0     [{'name': 'AST Studios', 'id': 75277}, {'name'...   2015-11-20  2015.0
# 1     [{'name': 'BigBen Films', 'id': 75835}, {'name...   2016-07-29  2016.0
# 2     [{'name': 'Revolver Film', 'id': 2046}, {'name...   2006-12-14  2006.0
# 3     [{'name': 'Fox Searchlight Pictures', 'id': 43...   2009-07-17  2009.0
# 4     [{'name': 'teamWorx', 'id': 425}, {'name': 'Fr...   2008-02-08  2008.0
# ...                                                 ...          ...     ...
# 9545  [{'name': 'Good Film Company', 'id': 5406}, {'...   2012-09-05  2012.0
# 9546  [{'name': 'Sidus', 'id': 3657}, {'name': 'Miro...   2010-05-13  2010.0
# 9547  [{'name': 'Polygon Entertainment', 'id': 5716}...   2009-06-06  2009.0
# 9548                  [{'name': 'Showbox', 'id': 3491}]   2012-10-11  2012.0
# 9549  [{'name': 'Cine Bazar', 'id': 5896}, {'name': ...   2008-08-19  2008.0
#
#                                                    cast  \
# 0     [{'cast_id': 0, 'character': "Alex's 12-Step F...
# 1     [{'cast_id': 0, 'character': 'Prashanth', 'cre...
# 2     [{'cast_id': 2, 'character': '', 'credit_id': ...
# 3     [{'cast_id': 4, 'character': 'Tom Hansen', 'cr...
# 4     [{'cast_id': 7, 'character': 'Pelle', 'credit_...
# ...                                                 ...
# 9545  [{'cast_id': 18, 'character': 'Mi-sun', 'credi...
# 9546  [{'cast_id': 3, 'character': 'Eun-yi', 'credit...
# 9547  [{'cast_id': 6, 'character': '김휘 (Kim Hwi)', '...
# 9548  [{'cast_id': 32, 'character': 'Ji Hyeong-do', ...
# 9549  [{'cast_id': 15, 'character': 'Kenji Endô', 'c...
#
#                                                    crew  \
# 0     [{'credit_id': '545bbabf0e0a261fb9002212', 'de...
# 1     [{'credit_id': '571862bbc3a3687fd60029dd', 'de...
# 2     [{'credit_id': '54d91816c3a3687ab90001d6', 'de...
# 3     [{'credit_id': '52fe47f99251416c750abaa5', 'de...
# 4     [{'credit_id': '52fe4496c3a36847f809e9bf', 'de...
# ...                                                 ...
# 9545  [{'credit_id': '52fe4a94c3a368484e15b787', 'de...
# 9546  [{'credit_id': '52fe46b5c3a36847f810dad9', 'de...
# 9547  [{'credit_id': '52fe45029251416c91024745', 'de...
# 9548  [{'credit_id': '53038895c3a3680a095b9c78', 'de...
# 9549  [{'credit_id': '57fc644ec3a368440f004c0d', 'de...
#
#                        director       director_id  \
# 0                  Tara Subkoff  /name/nm0836964/
# 1     Tharun Bhascker Dhaassyam  /name/nm5056902/
# 2              Martin Koolhoven  /name/nm0465551/
# 3                     Marc Webb  /name/nm1989536/
# 4                           NaN               NaN
# ...                         ...               ...
# 9545                 Kim Ki-duk  /name/nm1104118/
# 9546                Im Sang-soo  /name/nm0407992/
# 9547                    JK Youn  /name/nm1082740/
# 9548              Sang-yoon Lim  /name/nm5249757/
# 9549          Yukihiko Tsutsumi  /name/nm1066739/
#
#                                                    star  \
# 0     Sadie Seelert, \nHaley Murphy, \nBridget McGar...
# 1     Abhay Bethiganti, \nKeshav Deepak, \nVijay Dev...
# 2     Ad van Kempen, \nGeert de Jong, \nYes-R, \nTji...
# 3     Zooey Deschanel, \nJoseph Gordon-Levitt, \nGeo...
# 4                                                   NaN
# ...                                                 ...
# 9545  Min-soo Jo, \nLee Jung-Jin, \nKi-Hong Woo, \nE...
# 9546  Jeon Do-yeon, \nLee Jung-jae, \nYoun Yuh-jung,...
# 9547  Kim Yoo-jeong, \nHa Ji-Won, \nLee Min-ki, \nSo...
# 9548  So Ji-seob, \nMi-yeon Lee, \nKwak Do-won, \nDo...
# 9549  Toshiaki Karasawa, \nEtsushi Toyokawa, \nTakak...
#
#                                                 star_id
# 0     /name/nm6344380/,/name/nm4239131/,/name/nm5376...
# 1     /name/nm8232982/,/name/nm6642302/,/name/nm4797...
# 2     /name/nm0447397/,/name/nm0429522/,/name/nm2086...
# 3     /name/nm0221046/,/name/nm0330687/,/name/nm0034...
# 4                                                   NaN
# ...                                                 ...
# 9545  /name/nm5180933/,/name/nm1050125/,/name/nm5494...
# 9546  /name/nm0161133/,/name/nm0497631/,/name/nm0950...
# 9547  /name/nm2498552/,/name/nm0351710/,/name/nm2523...
# 9548  /name/nm1234414/,/name/nm0497870/,/name/nm3483...
# 9549  /name/nm0438960/,/name/nm0870317/,/name/nm0865...
#
# [9550 rows x 20 columns]

# %%
data.head()
# Out:
#                       final_title  final_budget  final_worldwide_boxoffice  \
# 0                         #Horror     1500000.0                        NaN
# 1                  #Pellichoopulu      200000.0                  5500000.0
# 2              'N Beetje Verliefd      800000.0                   966214.0
# 3            (500) Days of Summer     7500000.0                 60722734.0
# 4  1. Mai – Helden bei der Arbeit      200000.0                        NaN
#
#    final_domestic_boxoffice  \
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                32391374.0
# 4                       NaN
#
#                                         final_genres final_runtime  \
# 0  [{'id': 18, 'name': 'Drama'}, {'id': 9648, 'na...          90.0
# 1  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...         124.0
# 2  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...          83.0
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...          95.0
# 4                      [{'id': 18, 'name': 'Drama'}]          90.0
#
#                                       final_overview  final_certificate  \
# 0  Inspired by actual events, a group of 12 year ...                3.0
# 1  Raj Kandukuri and BiG Ben Films in association...                8.2
# 2  Thijs is a ripe-age Dutch tomato grower. His a...                5.4
# 3  Tom (Joseph Gordon-Levitt), greeting-card writ...                7.7
# 4  An eleven-year-old Turkish boy, two young men ...                NaN
#
#   final_original_language                         final_production_countries  \
# 0                      de  [{'iso_3166_1': 'US', 'name': 'United States o...
# 1                      te            [{'iso_3166_1': 'IN', 'name': 'India'}]
# 2                      nl      [{'iso_3166_1': 'NL', 'name': 'Netherlands'}]
# 3                      en  [{'iso_3166_1': 'US', 'name': 'United States o...
# 4                      de          [{'iso_3166_1': 'DE', 'name': 'Germany'}]
#
#      imdb_id                               production_companies release_date  \
# 0  tt3526286  [{'name': 'AST Studios', 'id': 75277}, {'name'...   2015-11-20
# 1  tt5824826  [{'name': 'BigBen Films', 'id': 75835}, {'name...   2016-07-29
# 2  tt0800164  [{'name': 'Revolver Film', 'id': 2046}, {'name...   2006-12-14
# 3  tt1022603  [{'name': 'Fox Searchlight Pictures', 'id': 43...   2009-07-17
# 4  tt1020932  [{'name': 'teamWorx', 'id': 425}, {'name': 'Fr...   2008-02-08
#
#      year                                               cast  \
# 0  2015.0  [{'cast_id': 0, 'character': "Alex's 12-Step F...
# 1  2016.0  [{'cast_id': 0, 'character': 'Prashanth', 'cre...
# 2  2006.0  [{'cast_id': 2, 'character': '', 'credit_id': ...
# 3  2009.0  [{'cast_id': 4, 'character': 'Tom Hansen', 'cr...
# 4  2008.0  [{'cast_id': 7, 'character': 'Pelle', 'credit_...
#
#                                                 crew  \
# 0  [{'credit_id': '545bbabf0e0a261fb9002212', 'de...
# 1  [{'credit_id': '571862bbc3a3687fd60029dd', 'de...
# 2  [{'credit_id': '54d91816c3a3687ab90001d6', 'de...
# 3  [{'credit_id': '52fe47f99251416c750abaa5', 'de...
# 4  [{'credit_id': '52fe4496c3a36847f809e9bf', 'de...
#
#                     director       director_id  \
# 0               Tara Subkoff  /name/nm0836964/
# 1  Tharun Bhascker Dhaassyam  /name/nm5056902/
# 2           Martin Koolhoven  /name/nm0465551/
# 3                  Marc Webb  /name/nm1989536/
# 4                        NaN               NaN
#
#                                                 star  \
# 0  Sadie Seelert, \nHaley Murphy, \nBridget McGar...
# 1  Abhay Bethiganti, \nKeshav Deepak, \nVijay Dev...
# 2  Ad van Kempen, \nGeert de Jong, \nYes-R, \nTji...
# 3  Zooey Deschanel, \nJoseph Gordon-Levitt, \nGeo...
# 4                                                NaN
#
#                                              star_id
# 0  /name/nm6344380/,/name/nm4239131/,/name/nm5376...
# 1  /name/nm8232982/,/name/nm6642302/,/name/nm4797...
# 2  /name/nm0447397/,/name/nm0429522/,/name/nm2086...
# 3  /name/nm0221046/,/name/nm0330687/,/name/nm0034...
# 4                                                NaN

# %%
#creating function that takes in a director name and a year, and then averages the rating of all the movies before that year.

def director_rating_before_year(Name, Year):
    rating = 0
    #for 
    return rating
