# %% [markdown]
# # Engineer feature variables

# %%
import numpy as np
import pandas as pd
import os
import pickle
from joblib import Parallel, delayed
import re
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as mpl
from ast import literal_eval

d = './raw_data/'

# %% [markdown]
# ### Import dataset

# %%
with open('processed_data/clean_build.pkl', 'rb') as filename:  
    clean_data = pickle.load(filename)
# Out:
# /var/folders/_q/50__mrnj2zv6hb8crhk3q46m0000gn/T/ipykernel_41005/3513447208.py:2: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   clean_data = pickle.load(filename)

# %%
clean_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6822 entries, 0 to 6821
# Data columns (total 39 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   title                     6822 non-null   object
#  1   budget                    6822 non-null   float64
#  2   worldwide_boxoffice       6822 non-null   float64
#  3   domestic_boxoffice        6822 non-null   float64
#  4   clean_title               6822 non-null   object
#  5   imdb_id                   6812 non-null   object
#  6   release_date              6766 non-null   object
#  7   year                      6766 non-null   float64
#  8   top_director              6822 non-null   object
#  9   top_cast                  6822 non-null   object
#  10  rating                    6822 non-null   float64
#  11  runtime                   6822 non-null   float64
#  12  original_language         6822 non-null   object
#  13  enrichment_source         6822 non-null   object
#  14  boxoffice_corrected       6822 non-null   int64
#  15  genres_list               6822 non-null   object
#  16  is_drama                  6822 non-null   int64
#  17  is_comedy                 6822 non-null   int64
#  18  is_action                 6822 non-null   int64
#  19  is_thriller               6822 non-null   int64
#  20  is_adventure              6822 non-null   int64
#  21  is_romance                6822 non-null   int64
#  22  is_crime                  6822 non-null   int64
#  23  is_science_fiction        6822 non-null   int64
#  24  is_horror                 6822 non-null   int64
#  25  is_family                 6822 non-null   int64
#  26  top_production_companies  6822 non-null   object
#  27  top_production_countries  6822 non-null   object
#  28  certificate               6822 non-null   object
#  29  decade                    6822 non-null   object
#  30  runtime_category          6822 non-null   object
#  31  release_month             6766 non-null   float64
#  32  is_Winter_Holiday         6822 non-null   int64
#  33  is_Summer                 6822 non-null   int64
#  34  is_Awards                 6822 non-null   int64
#  35  is_Spring                 6822 non-null   int64
#  36  is_Fall                   6822 non-null   int64
#  37  top_director_id           6822 non-null   object
#  38  top_cast_id               6822 non-null   object
# dtypes: float64(7), int64(16), object(16)
# memory usage: 2.0+ MB

# %% [markdown]
# ### Define functions for feature engineering

# %%
#function to adjust for inflation, input the number and year and it will say the value adjusted for inflation to 2025
from scipy.stats import gmean

def adjust_inflation(num, year):
    diff = 2025 - year
    final_num = num * (1.0325)**diff
    return final_num
    
# def get_entry(x, entry = 'name', rank = 0):
#     if isinstance(x, list):
#         entries = [i[entry] for i in x]
#         # keep only top 3 entries
#         if len(entries) > rank:
#             out = entries[rank]
#         else:
#             out = np.nan
#         return out

#     return np.nan

def get_entry(x, rank = 0):
    if isinstance(x, list) and len(x) > rank:
        out = x[rank]
    else:
        out = np.nan
    return out

    return np.nan

def value_before_year(x, variable = "actor_id_1", category = "top_cast", value_field = "wroi", period = 5, data = clean_data):

    use_data = data.loc[(x['year'] > data['year'])*((x['year'] - period) <= data['year'])]
    if len(use_data) > 0 and isinstance(x[variable], str):
        mask = np.array([x[variable] in entry for entry in use_data[category]]) #if variable != 'director_id' else np.array([x[variable] == entry for entry in use_data[category]])
        if np.sum(mask) > 0:
            vallist = use_data[mask]
            # Compute geometric mean
            value = vallist[value_field].apply(lambda row: gmean(row.dropna()), axis=0)
        else:
            value = 0
    else:
        value = 0
    return value

# %%
# Create adjusted revenue variables
clean_data.loc[:, 'adjusted_worldwide_boxoffice'] = adjust_inflation(clean_data['worldwide_boxoffice'], clean_data['year'])
clean_data.loc[:, 'adjusted_domestic_boxoffice'] = adjust_inflation(clean_data['domestic_boxoffice'], clean_data['year'])
clean_data.loc[:, 'adjusted_budget'] = adjust_inflation(clean_data['budget'], clean_data['year'])
clean_data.loc[:,'wroi'] = clean_data['adjusted_worldwide_boxoffice']/clean_data['adjusted_budget']
clean_data.loc[:,'droi'] = clean_data['adjusted_domestic_boxoffice']/clean_data['adjusted_budget']

# Split string variables
for i in np.arange(0,3):
    clean_data.loc[:, 'director_name_'+str(i + 1)] = clean_data['top_director'].apply(literal_eval).apply(get_entry, args = ([i]))
    clean_data.loc[:, 'director_id_'+str(i + 1)] = clean_data['top_director_id'].apply(literal_eval).apply(get_entry, args = ([i]))
    clean_data.loc[:, 'actor_name_'+str(i + 1)] = clean_data['top_cast'].apply(literal_eval).apply(get_entry, args = ([i]))
    clean_data.loc[:, 'actor_id_'+str(i + 1)] = clean_data['top_cast_id'].apply(literal_eval).apply(get_entry, args = ([i]))
    clean_data.loc[:, 'genre_name_'+str(i + 1)] = clean_data['genres_list'].apply(literal_eval).apply(get_entry, args = ([i]))
    clean_data.loc[:, 'production_country_'+str(i + 1)] = clean_data['top_production_countries'].apply(literal_eval).apply(get_entry, args = ([i]))
    clean_data.loc[:, 'production_company_'+str(i + 1)] = clean_data['top_production_companies'].apply(literal_eval).apply(get_entry, args = ([i]))

# Praneed insert code for other features here #
clean_data.loc[:,'is_language_english'] = (clean_data['original_language'] == "English")*1
clean_data.loc[:,'is_production_usa'] = 1*((clean_data['production_country_1'] == "United States of America") + (clean_data['production_country_2'] == "United States of America") + (clean_data['production_country_3'] == "United States of America") > 0)

# %%
# Check that variable values make sense
clean_data.describe().T
# Out:
#                                count          mean           std          min  \
# budget                        6822.0  3.331012e+07  4.357117e+07     1.000000
# worldwide_boxoffice           6822.0  9.664417e+07  1.853715e+08    30.000000
# domestic_boxoffice            6822.0  4.361615e+07  7.142061e+07     0.000000
# year                          6766.0  2.003467e+03  1.428892e+01  1915.000000
# rating                        6822.0  6.440879e+00  8.733453e-01     1.000000
# runtime                       6822.0  1.087986e+02  2.150746e+01     4.000000
# boxoffice_corrected           6822.0  3.107593e-02  1.735357e-01     0.000000
# is_drama                      6822.0  4.777191e-01  4.995399e-01     0.000000
# is_comedy                     6822.0  3.601583e-01  4.800813e-01     0.000000
# is_action                     6822.0  2.531516e-01  4.348489e-01     0.000000
# is_thriller                   6822.0  2.525652e-01  4.345155e-01     0.000000
# is_adventure                  6822.0  1.945177e-01  3.958580e-01     0.000000
# is_romance                    6822.0  1.909997e-01  3.931176e-01     0.000000
# is_crime                      6822.0  1.630021e-01  3.693946e-01     0.000000
# is_science_fiction            6822.0  1.122838e-01  3.157384e-01     0.000000
# is_horror                     6822.0  1.196130e-01  3.245323e-01     0.000000
# is_family                     6822.0  1.084726e-01  3.109991e-01     0.000000
# release_month                 6766.0  6.996896e+00  3.379800e+00     1.000000
# is_Winter_Holiday             6822.0  1.833773e-01  3.870039e-01     0.000000
# is_Summer                     6822.0  3.273234e-01  4.692708e-01     0.000000
# is_Awards                     6822.0  1.248901e-01  3.306184e-01     0.000000
# is_Spring                     6822.0  1.505424e-01  3.576284e-01     0.000000
# is_Fall                       6822.0  2.056582e-01  4.042114e-01     0.000000
# adjusted_worldwide_boxoffice  6766.0  1.834837e+08  3.344193e+08    55.084879
# adjusted_domestic_boxoffice   6766.0  8.953380e+07  1.440554e+08     0.000000
# adjusted_budget               6766.0  6.097635e+07  7.343939e+07     1.564807
# wroi                          6766.0  1.076809e+04  3.735769e+05     0.000011
# droi                          6766.0  7.318019e+03  3.124613e+05     0.000000
# director_id_2                    0.0           NaN           NaN          NaN
# director_id_3                    0.0           NaN           NaN          NaN
# is_language_english           6822.0  8.100264e-01  3.923088e-01     0.000000
# is_production_usa             6822.0  7.883319e-01  4.085207e-01     0.000000
#
#                                        25%           50%           75%  \
# budget                        6.000000e+06  1.800000e+07  4.000000e+07
# worldwide_boxoffice           7.566388e+06  3.121148e+07  1.008509e+08
# domestic_boxoffice            3.233793e+06  1.884661e+07  5.289710e+07
# year                          1.998000e+03  2.006000e+03  2.013000e+03
# rating                        5.900000e+00  6.500000e+00  7.000000e+00
# runtime                       9.500000e+01  1.050000e+02  1.190000e+02
# boxoffice_corrected           0.000000e+00  0.000000e+00  0.000000e+00
# is_drama                      0.000000e+00  0.000000e+00  1.000000e+00
# is_comedy                     0.000000e+00  0.000000e+00  1.000000e+00
# is_action                     0.000000e+00  0.000000e+00  1.000000e+00
# is_thriller                   0.000000e+00  0.000000e+00  1.000000e+00
# is_adventure                  0.000000e+00  0.000000e+00  0.000000e+00
# is_romance                    0.000000e+00  0.000000e+00  0.000000e+00
# is_crime                      0.000000e+00  0.000000e+00  0.000000e+00
# is_science_fiction            0.000000e+00  0.000000e+00  0.000000e+00
# is_horror                     0.000000e+00  0.000000e+00  0.000000e+00
# is_family                     0.000000e+00  0.000000e+00  0.000000e+00
# release_month                 4.000000e+00  7.000000e+00  1.000000e+01
# is_Winter_Holiday             0.000000e+00  0.000000e+00  0.000000e+00
# is_Summer                     0.000000e+00  0.000000e+00  1.000000e+00
# is_Awards                     0.000000e+00  0.000000e+00  0.000000e+00
# is_Spring                     0.000000e+00  0.000000e+00  0.000000e+00
# is_Fall                       0.000000e+00  0.000000e+00  0.000000e+00
# adjusted_worldwide_boxoffice  1.587570e+07  6.533244e+07  2.004793e+08
# adjusted_domestic_boxoffice   6.805597e+06  4.004119e+07  1.113966e+08
# adjusted_budget               1.347851e+07  3.595777e+07  8.187382e+07
# wroi                          7.165707e-01  1.926366e+00  4.115124e+00
# droi                          3.316346e-01  9.658142e-01  2.224996e+00
# director_id_2                          NaN           NaN           NaN
# director_id_3                          NaN           NaN           NaN
# is_language_english           1.000000e+00  1.000000e+00  1.000000e+00
# is_production_usa             1.000000e+00  1.000000e+00  1.000000e+00
#
#                                        max
# budget                        4.000000e+08
# worldwide_boxoffice           2.748243e+09
# domestic_boxoffice            9.366622e+08
# year                          2.025000e+03
# rating                        1.000000e+01
# runtime                       3.390000e+02
# boxoffice_corrected           1.000000e+00
# is_drama                      1.000000e+00
# is_comedy                     1.000000e+00
# is_action                     1.000000e+00
# is_thriller                   1.000000e+00
# is_adventure                  1.000000e+00
# is_romance                    1.000000e+00
# is_crime                      1.000000e+00
# is_science_fiction            1.000000e+00
# is_horror                     1.000000e+00
# is_family                     1.000000e+00
# release_month                 1.200000e+01
# is_Winter_Holiday             1.000000e+00
# is_Summer                     1.000000e+00
# is_Awards                     1.000000e+00
# is_Spring                     1.000000e+00
# is_Fall                       1.000000e+00
# adjusted_worldwide_boxoffice  6.263206e+09
# adjusted_domestic_boxoffice   3.109507e+09
# adjusted_budget               2.127799e+09
# wroi                          2.120000e+07
# droi                          2.120000e+07
# director_id_2                          NaN
# director_id_3                          NaN
# is_language_english           1.000000e+00
# is_production_usa             1.000000e+00

# %%
clean_data.sort_values(by ="wroi", ascending=False)[['title','budget', 'worldwide_boxoffice', 'year','release_date', 'wroi']]
# Out:
#                           title      budget  worldwide_boxoffice    year  \
# 1705  Every Which Way But Loose         5.0          106000000.0  1978.0
# 816                         Boy         3.0           43551154.0  2010.0
# 2951             Less Than Zero         1.0           12396383.0  1987.0
# 3368               Modern Times         1.0            8500000.0  1936.0
# 3054               Lost & Found         1.0            6545360.0  1999.0
# ...                         ...         ...                  ...     ...
# 5686         The Molly Maguires  11000000.0            2200000.0     NaN
# 5738             The Nutcracker  19000000.0            2119994.0     NaN
# 5868                   The Reef  10000000.0           15037867.0     NaN
# 6250                    Tracker   6500000.0               3149.0     NaN
# 6524      Welcome to Dongmakgol   8000000.0           48000000.0     NaN
#
#      release_date          wroi
# 1705   1978-12-19  2.120000e+07
# 816    2010-02-14  1.451705e+07
# 2951   1987-11-06  1.239638e+07
# 3368   1936-02-05  8.500000e+06
# 3054   1999-04-23  6.545360e+06
# ...           ...           ...
# 5686          NaN           NaN
# 5738          NaN           NaN
# 5868          NaN           NaN
# 6250          NaN           NaN
# 6524          NaN           NaN
#
# [6822 rows x 6 columns]

# %%
# Check for outliers in ROI
fig, axs = plt.subplots(1, 1, figsize=(5, 5))

im = axs.scatter(clean_data['adjusted_budget'], clean_data['adjusted_worldwide_boxoffice'], 
            c = clean_data['wroi'], cmap = "Purples", norm = mpl.colors.LogNorm())
axs.plot(np.linspace(1, np.amax(clean_data['adjusted_budget']), 20),
         np.linspace(1, np.amax(clean_data['adjusted_worldwide_boxoffice']), 20))
axs.axvline(x = 10000, color = 'k', linestyle = "--")
plt.semilogx()
plt.semilogy()

axs.minorticks_off()
axs.set_box_aspect(1)
axs.tick_params(axis='both', which='major', labelsize=8)

cb = fig.colorbar(im, ax=axs, orientation='vertical', shrink = 0.75, pad = 0.05)
cb.set_label("Worldwide ROI", fontsize = 11)
cb.ax.tick_params(labelsize=8)
axs.set_xlabel("Adjusted budget", fontsize = 12)
axs.set_ylabel("Adjusted world boxoffice", fontsize = 12)
# Out:
# Text(0, 0.5, 'Adjusted world boxoffice')

# %% [markdown]
# This motivates setting the budget cutoff at $10000

# %%
# Check for outliers in ratings
fig, axs = plt.subplots(1, 1, figsize=(5, 5))

im = axs.scatter(clean_data['adjusted_budget'], clean_data['adjusted_worldwide_boxoffice'], 
            c = clean_data['rating'], cmap = "Purples", norm = mpl.colors.Normalize())
axs.plot(np.linspace(1, np.amax(clean_data['adjusted_budget']), 20),
         np.linspace(1, np.amax(clean_data['adjusted_worldwide_boxoffice']), 20))
axs.axvline(x = 10000, color = 'k', linestyle = "--")
plt.semilogx()
plt.semilogy()

axs.minorticks_off()
axs.set_box_aspect(1)
axs.tick_params(axis='both', which='major', labelsize=8)

cb = fig.colorbar(im, ax=axs, orientation='vertical', shrink = 0.75, pad = 0.05)
cb.set_label("Rating", fontsize = 11)
cb.ax.tick_params(labelsize=8)
axs.set_xlabel("Adjusted budget", fontsize = 12)
axs.set_ylabel("Adjusted world boxoffice", fontsize = 12)
# Out:
# Text(0, 0.5, 'Adjusted world boxoffice')

# %%
# Filter dataset
for_analysis = clean_data.loc[(clean_data.adjusted_budget >= 10000)].copy()
for_analysis.describe().T
# Out:
#                                count          mean           std  \
# budget                        6741.0  3.363265e+07  4.371985e+07
# worldwide_boxoffice           6741.0  9.762585e+07  1.862460e+08
# domestic_boxoffice            6741.0  4.405140e+07  7.170556e+07
# year                          6741.0  2.003501e+03  1.424734e+01
# rating                        6741.0  6.444718e+00  8.723215e-01
# runtime                       6741.0  1.088809e+02  2.149835e+01
# boxoffice_corrected           6741.0  2.892746e-02  1.676151e-01
# is_drama                      6741.0  4.778223e-01  4.995450e-01
# is_comedy                     6741.0  3.595906e-01  4.799160e-01
# is_action                     6741.0  2.536716e-01  4.351441e-01
# is_thriller                   6741.0  2.535232e-01  4.350601e-01
# is_adventure                  6741.0  1.946299e-01  3.959449e-01
# is_romance                    6741.0  1.898828e-01  3.922374e-01
# is_crime                      6741.0  1.639223e-01  3.702325e-01
# is_science_fiction            6741.0  1.127429e-01  3.163017e-01
# is_horror                     6741.0  1.194185e-01  3.243044e-01
# is_family                     6741.0  1.082925e-01  3.107726e-01
# release_month                 6741.0  6.996143e+00  3.380646e+00
# is_Winter_Holiday             6741.0  1.851357e-01  3.884365e-01
# is_Summer                     6741.0  3.299214e-01  4.702192e-01
# is_Awards                     6741.0  1.257974e-01  3.316454e-01
# is_Spring                     6741.0  1.520546e-01  3.591004e-01
# is_Fall                       6741.0  2.070909e-01  4.052513e-01
# adjusted_worldwide_boxoffice  6741.0  1.839293e+08  3.348794e+08
# adjusted_domestic_boxoffice   6741.0  8.967021e+07  1.441199e+08
# adjusted_budget               6741.0  6.120249e+07  7.348133e+07
# wroi                          6741.0  6.851089e+00  1.582514e+02
# droi                          6741.0  3.927893e+00  8.862908e+01
# director_id_2                    0.0           NaN           NaN
# director_id_3                    0.0           NaN           NaN
# is_language_english           6741.0  8.116007e-01  3.910597e-01
# is_production_usa             6741.0  7.909806e-01  4.066385e-01
#
#                                        min           25%           50%  \
# budget                         6000.000000  6.500000e+06  1.800000e+07
# worldwide_boxoffice              30.000000  7.847000e+06  3.189725e+07
# domestic_boxoffice                0.000000  3.444895e+06  1.920274e+07
# year                           1915.000000  1.998000e+03  2.006000e+03
# rating                            1.000000  5.920000e+00  6.500000e+00
# runtime                           4.000000  9.500000e+01  1.050000e+02
# boxoffice_corrected               0.000000  0.000000e+00  0.000000e+00
# is_drama                          0.000000  0.000000e+00  0.000000e+00
# is_comedy                         0.000000  0.000000e+00  0.000000e+00
# is_action                         0.000000  0.000000e+00  0.000000e+00
# is_thriller                       0.000000  0.000000e+00  0.000000e+00
# is_adventure                      0.000000  0.000000e+00  0.000000e+00
# is_romance                        0.000000  0.000000e+00  0.000000e+00
# is_crime                          0.000000  0.000000e+00  0.000000e+00
# is_science_fiction                0.000000  0.000000e+00  0.000000e+00
# is_horror                         0.000000  0.000000e+00  0.000000e+00
# is_family                         0.000000  0.000000e+00  0.000000e+00
# release_month                     1.000000  4.000000e+00  7.000000e+00
# is_Winter_Holiday                 0.000000  0.000000e+00  0.000000e+00
# is_Summer                         0.000000  0.000000e+00  0.000000e+00
# is_Awards                         0.000000  0.000000e+00  0.000000e+00
# is_Spring                         0.000000  0.000000e+00  0.000000e+00
# is_Fall                           0.000000  0.000000e+00  0.000000e+00
# adjusted_worldwide_boxoffice     55.084879  1.610590e+07  6.558911e+07
# adjusted_domestic_boxoffice       0.000000  6.914843e+06  4.043043e+07
# adjusted_budget               12518.457856  1.376015e+07  3.627675e+07
# wroi                              0.000011  7.133636e-01  1.913352e+00
# droi                              0.000000  3.301031e-01  9.607023e-01
# director_id_2                          NaN           NaN           NaN
# director_id_3                          NaN           NaN           NaN
# is_language_english               0.000000  1.000000e+00  1.000000e+00
# is_production_usa                 0.000000  1.000000e+00  1.000000e+00
#
#                                        75%           max
# budget                        4.000000e+07  4.000000e+08
# worldwide_boxoffice           1.022366e+08  2.748243e+09
# domestic_boxoffice            5.342468e+07  9.366622e+08
# year                          2.013000e+03  2.025000e+03
# rating                        7.000000e+00  1.000000e+01
# runtime                       1.190000e+02  3.390000e+02
# boxoffice_corrected           0.000000e+00  1.000000e+00
# is_drama                      1.000000e+00  1.000000e+00
# is_comedy                     1.000000e+00  1.000000e+00
# is_action                     1.000000e+00  1.000000e+00
# is_thriller                   1.000000e+00  1.000000e+00
# is_adventure                  0.000000e+00  1.000000e+00
# is_romance                    0.000000e+00  1.000000e+00
# is_crime                      0.000000e+00  1.000000e+00
# is_science_fiction            0.000000e+00  1.000000e+00
# is_horror                     0.000000e+00  1.000000e+00
# is_family                     0.000000e+00  1.000000e+00
# release_month                 1.000000e+01  1.200000e+01
# is_Winter_Holiday             0.000000e+00  1.000000e+00
# is_Summer                     1.000000e+00  1.000000e+00
# is_Awards                     0.000000e+00  1.000000e+00
# is_Spring                     0.000000e+00  1.000000e+00
# is_Fall                       0.000000e+00  1.000000e+00
# adjusted_worldwide_boxoffice  2.013835e+08  6.263206e+09
# adjusted_domestic_boxoffice   1.117517e+08  3.109507e+09
# adjusted_budget               8.255273e+07  2.127799e+09
# wroi                          4.071249e+00  1.289039e+04
# droi                          2.196880e+00  7.194587e+03
# director_id_2                          NaN           NaN
# director_id_3                          NaN           NaN
# is_language_english           1.000000e+00  1.000000e+00
# is_production_usa             1.000000e+00  1.000000e+00

# %%
# Create variables to store rolling 5-year average ROI for each category
wroi_pairs = [['director_id_1', 'top_director_id', 'wroi'], ['director_id_2', 'top_director_id', 'wroi'], ['director_id_3', 'top_director_id', 'wroi'],
         ["actor_id_1", "top_cast_id", 'wroi'],["actor_id_2", "top_cast_id", 'wroi'], ["actor_id_3", "top_cast_id", 'wroi'],
         ["genre_name_1", "genres_list", 'wroi'],["genre_name_2", "genres_list", 'wroi'], ["genre_name_3", "genres_list", 'wroi'],
         ["production_company_1", "top_production_companies", 'wroi'],["production_company_2", "top_production_companies", 'wroi'], ["production_company_3", "top_production_companies", 'wroi']]

rating_pairs = [['director_id_1', 'top_director_id', 'rating'], ['director_id_2', 'top_director_id', 'rating'], ['director_id_3', 'top_director_id', 'rating'],
         ["actor_id_1", "top_cast_id", 'rating'],["actor_id_2", "top_cast_id", 'rating'], ["actor_id_3", "top_cast_id", 'rating'],
         ["genre_name_1", "genres_list", 'rating'],["genre_name_2", "genres_list", 'rating'], ["genre_name_3", "genres_list", 'rating'],
         ["production_company_1", "top_production_companies", 'rating'],["production_company_2", "top_production_companies", 'rating'], ["production_company_3", "top_production_companies", 'rating']]

for p in wroi_pairs + rating_pairs:
    for_analysis.loc[:, 'avg_'+p[2]+'_'+p[0]] = for_analysis.apply(value_before_year, args = ([p[0], p[1], p[2], 5, for_analysis]), axis = 1)

# %%
for_analysis.describe().T
# Out:
#                                   count          mean           std  \
# budget                           6741.0  3.363265e+07  4.371985e+07
# worldwide_boxoffice              6741.0  9.762585e+07  1.862460e+08
# domestic_boxoffice               6741.0  4.405140e+07  7.170556e+07
# year                             6741.0  2.003501e+03  1.424734e+01
# rating                           6741.0  6.444718e+00  8.723215e-01
# runtime                          6741.0  1.088809e+02  2.149835e+01
# boxoffice_corrected              6741.0  2.892746e-02  1.676151e-01
# is_drama                         6741.0  4.778223e-01  4.995450e-01
# is_comedy                        6741.0  3.595906e-01  4.799160e-01
# is_action                        6741.0  2.536716e-01  4.351441e-01
# is_thriller                      6741.0  2.535232e-01  4.350601e-01
# is_adventure                     6741.0  1.946299e-01  3.959449e-01
# is_romance                       6741.0  1.898828e-01  3.922374e-01
# is_crime                         6741.0  1.639223e-01  3.702325e-01
# is_science_fiction               6741.0  1.127429e-01  3.163017e-01
# is_horror                        6741.0  1.194185e-01  3.243044e-01
# is_family                        6741.0  1.082925e-01  3.107726e-01
# release_month                    6741.0  6.996143e+00  3.380646e+00
# is_Winter_Holiday                6741.0  1.851357e-01  3.884365e-01
# is_Summer                        6741.0  3.299214e-01  4.702192e-01
# is_Awards                        6741.0  1.257974e-01  3.316454e-01
# is_Spring                        6741.0  1.520546e-01  3.591004e-01
# is_Fall                          6741.0  2.070909e-01  4.052513e-01
# adjusted_worldwide_boxoffice     6741.0  1.839293e+08  3.348794e+08
# adjusted_domestic_boxoffice      6741.0  8.967021e+07  1.441199e+08
# adjusted_budget                  6741.0  6.120249e+07  7.348133e+07
# wroi                             6741.0  6.851089e+00  1.582514e+02
# droi                             6741.0  3.927893e+00  8.862908e+01
# director_id_2                       0.0           NaN           NaN
# director_id_3                       0.0           NaN           NaN
# is_language_english              6741.0  8.116007e-01  3.910597e-01
# is_production_usa                6741.0  7.909806e-01  4.066385e-01
# avg_wroi_director_id_1           6741.0  2.550203e+00  1.200544e+01
# avg_wroi_director_id_2           6741.0  0.000000e+00  0.000000e+00
# avg_wroi_director_id_3           6741.0  0.000000e+00  0.000000e+00
# avg_wroi_actor_id_1              6741.0  4.681736e+00  9.539783e+01
# avg_wroi_actor_id_2              6741.0  2.383980e+00  7.491008e+00
# avg_wroi_actor_id_3              6741.0  1.840990e+00  5.986817e+00
# avg_wroi_genre_name_1            6741.0  6.458753e+00  1.455065e+01
# avg_wroi_genre_name_2            6741.0  4.955746e+00  1.213113e+01
# avg_wroi_genre_name_3            6741.0  3.460020e+00  1.164639e+01
# avg_wroi_production_company_1    6741.0  3.493148e+00  1.237737e+01
# avg_wroi_production_company_2    6741.0  5.500637e+00  1.703383e+02
# avg_wroi_production_company_3    6741.0  4.980920e+00  1.803055e+02
# avg_rating_director_id_1         6741.0  2.912374e+00  3.317207e+00
# avg_rating_director_id_2         6741.0  0.000000e+00  0.000000e+00
# avg_rating_director_id_3         6741.0  0.000000e+00  0.000000e+00
# avg_rating_actor_id_1            6741.0  4.538025e+00  3.070388e+00
# avg_rating_actor_id_2            6741.0  3.753303e+00  3.244568e+00
# avg_rating_actor_id_3            6741.0  3.158714e+00  3.257697e+00
# avg_rating_genre_name_1          6741.0  6.380879e+00  5.129223e-01
# avg_rating_genre_name_2          6741.0  5.576613e+00  2.205377e+00
# avg_rating_genre_name_3          6741.0  3.596961e+00  3.196803e+00
# avg_rating_production_company_1  6741.0  4.520290e+00  2.993843e+00
# avg_rating_production_company_2  6741.0  3.470860e+00  3.257943e+00
# avg_rating_production_company_3  6741.0  2.297572e+00  3.109355e+00
#
#                                           min           25%           50%  \
# budget                            6000.000000  6.500000e+06  1.800000e+07
# worldwide_boxoffice                 30.000000  7.847000e+06  3.189725e+07
# domestic_boxoffice                   0.000000  3.444895e+06  1.920274e+07
# year                              1915.000000  1.998000e+03  2.006000e+03
# rating                               1.000000  5.920000e+00  6.500000e+00
# runtime                              4.000000  9.500000e+01  1.050000e+02
# boxoffice_corrected                  0.000000  0.000000e+00  0.000000e+00
# is_drama                             0.000000  0.000000e+00  0.000000e+00
# is_comedy                            0.000000  0.000000e+00  0.000000e+00
# is_action                            0.000000  0.000000e+00  0.000000e+00
# is_thriller                          0.000000  0.000000e+00  0.000000e+00
# is_adventure                         0.000000  0.000000e+00  0.000000e+00
# is_romance                           0.000000  0.000000e+00  0.000000e+00
# is_crime                             0.000000  0.000000e+00  0.000000e+00
# is_science_fiction                   0.000000  0.000000e+00  0.000000e+00
# is_horror                            0.000000  0.000000e+00  0.000000e+00
# is_family                            0.000000  0.000000e+00  0.000000e+00
# release_month                        1.000000  4.000000e+00  7.000000e+00
# is_Winter_Holiday                    0.000000  0.000000e+00  0.000000e+00
# is_Summer                            0.000000  0.000000e+00  0.000000e+00
# is_Awards                            0.000000  0.000000e+00  0.000000e+00
# is_Spring                            0.000000  0.000000e+00  0.000000e+00
# is_Fall                              0.000000  0.000000e+00  0.000000e+00
# adjusted_worldwide_boxoffice        55.084879  1.610590e+07  6.558911e+07
# adjusted_domestic_boxoffice          0.000000  6.914843e+06  4.043043e+07
# adjusted_budget                  12518.457856  1.376015e+07  3.627675e+07
# wroi                                 0.000011  7.133636e-01  1.913352e+00
# droi                                 0.000000  3.301031e-01  9.607023e-01
# director_id_2                             NaN           NaN           NaN
# director_id_3                             NaN           NaN           NaN
# is_language_english                  0.000000  1.000000e+00  1.000000e+00
# is_production_usa                    0.000000  1.000000e+00  1.000000e+00
# avg_wroi_director_id_1               0.000000  0.000000e+00  0.000000e+00
# avg_wroi_director_id_2               0.000000  0.000000e+00  0.000000e+00
# avg_wroi_director_id_3               0.000000  0.000000e+00  0.000000e+00
# avg_wroi_actor_id_1                  0.000000  0.000000e+00  1.837575e+00
# avg_wroi_actor_id_2                  0.000000  0.000000e+00  8.930964e-01
# avg_wroi_actor_id_3                  0.000000  0.000000e+00  0.000000e+00
# avg_wroi_genre_name_1                0.000000  2.831327e+00  3.176838e+00
# avg_wroi_genre_name_2                0.000000  2.497796e+00  3.066801e+00
# avg_wroi_genre_name_3                0.000000  0.000000e+00  2.360291e+00
# avg_wroi_production_company_1        0.000000  0.000000e+00  2.283181e+00
# avg_wroi_production_company_2        0.000000  0.000000e+00  7.175646e-01
# avg_wroi_production_company_3        0.000000  0.000000e+00  0.000000e+00
# avg_rating_director_id_1             0.000000  0.000000e+00  0.000000e+00
# avg_rating_director_id_2             0.000000  0.000000e+00  0.000000e+00
# avg_rating_director_id_3             0.000000  0.000000e+00  0.000000e+00
# avg_rating_actor_id_1                0.000000  0.000000e+00  6.275100e+00
# avg_rating_actor_id_2                0.000000  0.000000e+00  5.900000e+00
# avg_rating_actor_id_3                0.000000  0.000000e+00  0.000000e+00
# avg_rating_genre_name_1              0.000000  6.202111e+00  6.374738e+00
# avg_rating_genre_name_2              0.000000  6.174464e+00  6.341584e+00
# avg_rating_genre_name_3              0.000000  0.000000e+00  6.160592e+00
# avg_rating_production_company_1      0.000000  0.000000e+00  6.232238e+00
# avg_rating_production_company_2      0.000000  0.000000e+00  5.775000e+00
# avg_rating_production_company_3      0.000000  0.000000e+00  0.000000e+00
#
#                                           75%           max
# budget                           4.000000e+07  4.000000e+08
# worldwide_boxoffice              1.022366e+08  2.748243e+09
# domestic_boxoffice               5.342468e+07  9.366622e+08
# year                             2.013000e+03  2.025000e+03
# rating                           7.000000e+00  1.000000e+01
# runtime                          1.190000e+02  3.390000e+02
# boxoffice_corrected              0.000000e+00  1.000000e+00
# is_drama                         1.000000e+00  1.000000e+00
# is_comedy                        1.000000e+00  1.000000e+00
# is_action                        1.000000e+00  1.000000e+00
# is_thriller                      1.000000e+00  1.000000e+00
# is_adventure                     0.000000e+00  1.000000e+00
# is_romance                       0.000000e+00  1.000000e+00
# is_crime                         0.000000e+00  1.000000e+00
# is_science_fiction               0.000000e+00  1.000000e+00
# is_horror                        0.000000e+00  1.000000e+00
# is_family                        0.000000e+00  1.000000e+00
# release_month                    1.000000e+01  1.200000e+01
# is_Winter_Holiday                0.000000e+00  1.000000e+00
# is_Summer                        1.000000e+00  1.000000e+00
# is_Awards                        0.000000e+00  1.000000e+00
# is_Spring                        0.000000e+00  1.000000e+00
# is_Fall                          0.000000e+00  1.000000e+00
# adjusted_worldwide_boxoffice     2.013835e+08  6.263206e+09
# adjusted_domestic_boxoffice      1.117517e+08  3.109507e+09
# adjusted_budget                  8.255273e+07  2.127799e+09
# wroi                             4.071249e+00  1.289039e+04
# droi                             2.196880e+00  7.194587e+03
# director_id_2                             NaN           NaN
# director_id_3                             NaN           NaN
# is_language_english              1.000000e+00  1.000000e+00
# is_production_usa                1.000000e+00  1.000000e+00
# avg_wroi_director_id_1           2.448603e+00  7.000000e+02
# avg_wroi_director_id_2           0.000000e+00  0.000000e+00
# avg_wroi_director_id_3           0.000000e+00  0.000000e+00
# avg_wroi_actor_id_1              3.412883e+00  6.474779e+03
# avg_wroi_actor_id_2              2.792742e+00  2.162277e+02
# avg_wroi_actor_id_3              2.258685e+00  1.822571e+02
# avg_wroi_genre_name_1            4.334086e+00  1.407801e+02
# avg_wroi_genre_name_2            3.820867e+00  1.336417e+02
# avg_wroi_genre_name_3            3.216084e+00  1.337728e+02
# avg_wroi_production_company_1    3.599519e+00  6.538462e+02
# avg_wroi_production_company_2    2.910512e+00  1.289039e+04
# avg_wroi_production_company_3    1.975185e+00  1.289039e+04
# avg_rating_director_id_1         6.500000e+00  8.708000e+00
# avg_rating_director_id_2         0.000000e+00  0.000000e+00
# avg_rating_director_id_3         0.000000e+00  0.000000e+00
# avg_rating_actor_id_1            6.735000e+00  8.700000e+00
# avg_rating_actor_id_2            6.600000e+00  8.566000e+00
# avg_rating_actor_id_3            6.463333e+00  8.708000e+00
# avg_rating_genre_name_1          6.558028e+00  8.300000e+00
# avg_rating_genre_name_2          6.549404e+00  8.500000e+00
# avg_rating_genre_name_3          6.417160e+00  8.020667e+00
# avg_rating_production_company_1  6.570528e+00  8.538000e+00
# avg_rating_production_company_2  6.500000e+00  8.600000e+00
# avg_rating_production_company_3  6.247516e+00  8.467000e+00

# %%
for_analysis.sort_values(by ="wroi", ascending=False)[['title','budget', 'worldwide_boxoffice', 'year','release_date', 'wroi']]
# Out:
#                      title      budget  worldwide_boxoffice    year  \
# 3776   Paranormal Activity     15000.0          193355800.0  2007.0
# 1666            Eraserhead     10000.0            7000000.0  1977.0
# 6794                  猛龍過江    130000.0           85000000.0  1972.0
# 3869        Pink Flamingos     12000.0            6000000.0  1972.0
# 5287           The Gallows    100000.0           42964410.0  2015.0
# ...                    ...         ...                  ...     ...
# 940          Capricorn One   5000000.0                401.0  1977.0
# 393          A Perfect Man   5000000.0                388.0  2013.0
# 6091  The Walking Deceased   2000000.0                 43.0  2015.0
# 6732           Zyzzyx Road   2000000.0                 30.0  2006.0
# 4003                 Putin  14000000.0                150.0  2025.0
#
#      release_date          wroi
# 3776   2007-09-14  12890.386667
# 1666   1977-03-19    700.000000
# 6794   1972-06-01    653.846154
# 3869   1972-03-12    500.000000
# 5287   2015-07-09    429.644100
# ...           ...           ...
# 940    1977-12-10      0.000080
# 393    2013-11-01      0.000078
# 6091   2015-03-20      0.000022
# 6732   2006-02-25      0.000015
# 4003   2025-01-09      0.000011
#
# [6741 rows x 6 columns]

# %% [markdown]
# ### Export dataset

# %%
with open('processed_data/analysis_build.pkl', 'wb') as f:
    pickle.dump(for_analysis, f)
